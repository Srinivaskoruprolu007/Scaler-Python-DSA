# %%
print(21334534567654567894567898765434567876543)
# Out:
# 21334534567654567894567898765434567876543

# %%
print(4.64345676543234)
# Out:
# 4.64345676543234

# %%
print(True)
print(False)
# Out:
# True
# False

# %%
print("Both double quotes")
print('Both single quotes')
# Out:
# Both double quotes
# Both single quotes

# %%
print("This is not okay')

#Combination of doble and single quotes are not allowed
# Out:
#   Cell In[7], line 1
#     print("This is not okay')
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print(4 + 6j)
# Out:
# (4+6j)

# %%
print(None)
# Out:
# None

# %%
print(type(5))
# Out:
# <class 'int'>

# %%
print(type(0.5))
# Out:
# <class 'float'>

# %%
print(type("What type am i ?"))
# Out:
# <class 'str'>

# %%
print(type(False))
print(type(True))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
print(type(6 + 4j))
# Out:
# <class 'complex'>

# %%
x = 5 # defining a variable
print(type(x))
# Out:
# <class 'int'>

# %%
y = "The variable can be any value !"
print(y)
# Out:
# The variable can be any value !

# %% [markdown]
# ### There are 2 rules to creating variable in python
# 1. Variable name should be a valid identifier (alphanumeric characters and underscore)
# 2. Variable names can't start with numbers or special symbols like $, @ etc..

# %%
random = 123
Random = 123
_random = 123
123random = 123 # a number can't be starting of a variable
# Out:
#   Cell In[6], line 4
#     123random = 123 # a number can't be starting of a variable
#       ^
# SyntaxError: invalid decimal literal

# %%
random123 = 123

random_123 = 123

Random_something_123 = 123

# %%
random@123 = 123
# Out:
#   Cell In[8], line 1
#     random@123 = 123
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
print(56.6, 7, 'random', True)
# Out:
# 56.6 7 random True

# %%
print(56, "+", 6.7, "+", "random", "+", True)
# Out:
# 56 + 6.7 + random + True

# %%
print(56, 6.7, "random", True, sep = " + ")
# Out:
# 56 + 6.7 + random + True

# %%
print(56.6, 7.5, "random", sep = "__+__")
# Out:
# 56.6__+__7.5__+__random

# %%
print("line1") # the default end character after print is \n
print("line2")
print("line3")
# Out:
# line1
# line2
# line3

# %%
print('Line 1 ', end = " - ")
print('Line 2 ', end = " - ")
print('Line 3')
# Out:
# Line 1  - Line 2  - Line 3

# %%
print(1, 2, 3, sep = "+", end = "THIS IS THE END")
print(4, 5, sep = "__")
# Out:
# 1+2+3THIS IS THE END4__5

# %% [markdown]
# Default values for SEP and END
#
# 1.SEP = ""
#
# 2.END = "\n"

# %%
print(1, 2, 3, 4, 5, sep = "\n")
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### Taking Input from User

# %%
any_variable_name = input()
print(any_variable_name)
# Out:
# Hello

# %%
print(type(any_variable_name))
# Out:
# <class 'str'>

# %%
num1 = input()
num2 = input()
print((num1) + (num2))
# Out:
# 1010

# %%
print("10"+"15")
# Out:
# 1015

# %%
x = "12345"
x_int = int(x)
print(x_int)
print(type(x_int))
# Out:
# 12345
# <class 'int'>

# %%
x_float = float(x)
print(x_float)
print(type(x_float))
# Out:
# 12345.0
# <class 'float'>

# %%
x = 12345
anything_random = str(x)
print(anything_random)
print(type(anything_random))
# Out:
# 12345
# <class 'str'>

# %%
num1 = int(input())
num2 = int(input())

print(num1 + num2)
# Out:
# 30

# %%
num1 = int(input())
num2 = int(input())

print(num1 + num2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Sandeep\Desktop\Scaler-Python-DSA\Scaler-Python-DSA\1 - Data Types.ipynb Cell 37 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Sandeep/Desktop/Scaler-Python-DSA/Scaler-Python-DSA/1%20-%20Data%20Types.ipynb#X52sZmlsZQ%3D%3D?line=0'>1</a> num1 = int(input())
#       <a href='vscode-notebook-cell:/c%3A/Users/Sandeep/Desktop/Scaler-Python-DSA/Scaler-Python-DSA/1%20-%20Data%20Types.ipynb#X52sZmlsZQ%3D%3D?line=1'>2</a> num2 = int(input())
#       <a href='vscode-notebook-cell:/c%3A/Users/Sandeep/Desktop/Scaler-Python-DSA/Scaler-Python-DSA/1%20-%20Data%20Types.ipynb#X52sZmlsZQ%3D%3D?line=3'>4</a> print(num1 + num2)
#
# ValueError: invalid literal for int() with base 10: 'this is not int'

# %%
num1 = int(input("Please enter a valid integer - "))
num2 = int(input("Please enter a valid integer - "))

print(num1 + num2)
# Out:
# 46
